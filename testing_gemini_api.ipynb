# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.9/245.9 kB 8.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.15.1 requires google-genai!=1.37.0,!=1.38.0,!=1.39.0,<=1.40.0,>=1.21.1, but you have google-genai 1.41.0 which is incompatible.

# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyChamz-Fm4PqvgDLw8QRueMvU1gXc9SQ78'

# %%
from google import genai
from google.genai import types

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain what is a computer in an interview style"
)
print(response.text)
# Out:
# "That's an excellent question, as the definition of a computer has truly evolved over time!
#
# At its fundamental level, **a computer is an electronic device designed to accept, process, store, and output data according to a set of instructions.**
#
# Let me break that down a bit:
#
# 1.  **Electronic Device:** It operates using electrical signals, allowing for incredibly fast operations.
# 2.  **Accepts Data (Input):** It takes in information from various sources. This could be you typing on a keyboard, clicking a mouse, touching a screen, or receiving data from sensors, networks, or other storage devices.
# 3.  **Processes Data:** This is the core function, handled primarily by the Central Processing Unit (CPU). It performs calculations, manipulates information, and executes logical operations based on pre-defined instructions. This is where raw data is transformed into meaningful information.
# 4.  **Stores Data:** Computers have memory and storage components (like RAM and hard drives/SSDs) to hold both the instructions they need to operate (software) and the data they are working with, either temporarily or persistently.
# 5.  **Outputs Data:** After processing, the computer presents the results in a human-readable format or sends it to another device. This could be displaying information on a monitor, printing a document, playing audio, or sending data over a network.
# 6.  **According to a Set of Instructions (Software):** This is crucial. A computer isn't smart on its own; it follows precise, step-by-step instructions called 'software' or 'programs.' Without software, the hardware is just a collection of inert components.
#
# **In essence, a computer is an incredibly versatile and powerful tool that automates complex tasks, solves problems, and enables communication by faithfully executing instructions at high speed and with great accuracy.**
#
# From the supercomputer calculating weather patterns to the smartphone in your pocket, or even the small chip controlling your car's engine, they all adhere to these core principles."

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text=""""That's an excellent question, as the definition of a computer has truly evolved over time!
#
# At its fundamental level, **a computer is an electronic device designed to accept, process, store, and output data according to a set of instructions.**
#
# Let me break that down a bit:
#
# 1.  **Electronic Device:** It operates using electrical signals, allowing for incredibly fast operations.
# 2.  **Accepts Data (Input):** It takes in information from various sources. This could be you typing on a keyboard, clicking a mouse, touching a screen, or receiving data from sensors, networks, or other storage devices.
# 3.  **Processes Data:** This is the core function, handled primarily by the Central Processing Unit (CPU). It performs calculations, manipulates information, and executes logical operations based on pre-defined instructions. This is where raw data is transformed into meaningful information.
# 4.  **Stores Data:** Computers have memory and storage components (like RAM and hard drives/SSDs) to hold both the instructions they need to operate (software) and the data they are working with, either temporarily or persistently.
# 5.  **Outputs Data:** After processing, the computer presents the results in a human-readable format or sends it to another device. This could be displaying information on a monitor, printing a document, playing audio, or sending data over a network.
# 6.  **According to a Set of Instructions (Software):** This is crucial. A computer isn't smart on its own; it follows precise, step-by-step instructions called 'software' or 'programs.' Without software, the hardware is just a collection of inert components.
#
# **In essence, a computer is an incredibly versatile and powerful tool that automates complex tasks, solves problems, and enables communication by faithfully executing instructions at high speed and with great accuracy.**
#
# From the supercomputer calculating weather patterns to the smartphone in your pocket, or even the small chip controlling your car's engine, they all adhere to these core principles.""""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='zIHhaJ-OCKO-_uMP7O-KoQQ',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=418,
#     prompt_token_count=10,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=10
#       ),
#     ],
#     thoughts_token_count=1118,
#     total_token_count=1546
#   )
# )

# %%
import wave

# runtime: around 2s

# Set up the wave file to save the output:
def wave_file(filename, pcm, channels=1, rate=24000, sample_width=2):
   with wave.open(filename, "wb") as wf:
      wf.setnchannels(channels)
      wf.setsampwidth(sample_width)
      wf.setframerate(rate)
      wf.writeframes(pcm)

prompt = """TTS the following conversation between Joe and Jane:
         Joe: How's it going today Jane?
         Jane: Not too bad, how about you?"""

response = client.models.generate_content(
   model="gemini-2.5-flash-preview-tts",
   contents=prompt,
   config=types.GenerateContentConfig(
      response_modalities=["AUDIO"],
      speech_config=types.SpeechConfig(
         multi_speaker_voice_config=types.MultiSpeakerVoiceConfig(
            speaker_voice_configs=[
               types.SpeakerVoiceConfig(
                  speaker='Joe',
                  voice_config=types.VoiceConfig(
                     prebuilt_voice_config=types.PrebuiltVoiceConfig(
                        voice_name='Kore',
                     )
                  )
               ),
               types.SpeakerVoiceConfig(
                  speaker='Jane',
                  voice_config=types.VoiceConfig(
                     prebuilt_voice_config=types.PrebuiltVoiceConfig(
                        voice_name='Puck',
                     )
                  )
               ),
            ]
         )
      )
   )
)

data = response.candidates[0].content.parts[0].inline_data.data

file_name='out.wav'
wave_file(file_name, data) # Saves the file to current directory

# %%
from IPython.display import Audio
Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# runtime: 35s

transcript = client.models.generate_content(
   model="gemini-2.0-flash",
   contents="""Generate a short transcript around 100 words that reads
            like it was clipped from a podcast by excited herpetologists.
            The hosts names are Dr. Anya and Liam.""").text

response = client.models.generate_content(
   model="gemini-2.5-flash-preview-tts",
   contents=transcript,
   config=types.GenerateContentConfig(
      response_modalities=["AUDIO"],
      speech_config=types.SpeechConfig(
         multi_speaker_voice_config=types.MultiSpeakerVoiceConfig(
            speaker_voice_configs=[
               types.SpeakerVoiceConfig(
                  speaker='Dr. Anya',
                  voice_config=types.VoiceConfig(
                     prebuilt_voice_config=types.PrebuiltVoiceConfig(
                        voice_name='Kore',
                     )
                  )
               ),
               types.SpeakerVoiceConfig(
                  speaker='Liam',
                  voice_config=types.VoiceConfig(
                     prebuilt_voice_config=types.PrebuiltVoiceConfig(
                        voice_name='Puck',
                     )
                  )
               ),
            ]
         )
      )
   )
)

# %%
print(transcript)
# Out:
# **(Intro music fades quickly)**
#
# **Dr. Anya:** ...and I’m telling you, Liam, the iridescence! Never seen anything like it on a *Xenopeltis unicolor* before!
#
# **Liam:** Woah, woah, Anya, hold up! An albino Sunbeam snake with *that* level of rainbow sheen? Are you serious?
#
# **Dr. Anya:** Dead serious! Caught it during the night survey, near the old rubber plantation. Absolutely stunning!
#
# **Liam:** Man, I am green with envy! Photos? We NEED photos for the next HerpSoc newsletter.
#
# **Dr. Anya:** Already submitted, my friend! Plus, I got some great footage of its feeding response. Crickets vanished in a blink!
#
# **Liam:** (Laughing) You’re living the dream, Anya! Living the dream! That’s going straight to the top of my "Holy Grail Herp" list.

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             inline_data=Blob(
#               data=<... Max depth ...>,
#               mime_type=<... Max depth ...>
#             )
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash-preview-tts',
#   response_id='4ILhaJyOMrvzqtsPrsLIqQQ',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=1107,
#     candidates_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.AUDIO: 'AUDIO'>,
#         token_count=1107
#       ),
#     ],
#     prompt_token_count=201,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=201
#       ),
#     ],
#     total_token_count=1308
#   )
# )

# %%
# it is a bunch of bytes
data = response.candidates[0].content.parts[0].inline_data.data

# %%
file_name='out2.wav'
wave_file(file_name, data) # Saves the file to current directory
Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
